# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as function
import pyspark.sql.types as types

# %%
spark = (
    SparkSession.
    builder.
    appName('spark-paysim').
    getOrCreate()
)

# %%
filename = 'data/paysim.csv'

# %%
df = (
    spark.
    read.
    format('csv').
    option('header', 'true').
    option('inferSchema', 'true').
    load(filename)
)

# %%
df.show(n=10)
# Out:
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# |step|    type|  amount|   nameOrig|oldbalanceOrg|newbalanceOrig|   nameDest|oldbalanceDest|newbalanceDest|isFraud|isFlaggedFraud|
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# |   1| PAYMENT| 9839.64|C1231006815|     170136.0|     160296.36|M1979787155|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 1864.28|C1666544295|      21249.0|      19384.72|M2044282225|           0.0|           0.0|      0|             0|
# |   1|TRANSFER|   181.0|C1305486145|        181.0|           0.0| C553264065|           0.0|           0.0|      1|             0|
# |   1|CASH_OUT|   181.0| C840083671|        181.0|           0.0|  C38997010|       21182.0|           0.0|      1|             0|
# |   1| PAYMENT|11668.14|C2048537720|      41554.0|      29885.86|M1230701703|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 7817.71|  C90045638|      53860.0|      46042.29| M573487274|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 7107.77| C154988899|     183195.0|     176087.23| M408069119|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 7861.64|C1912850431|    176087.23|     168225.59| M633326333|           0.0|           0.0|      0|             0|
# |   1| PAYMENT| 4024.36|C1265012928|       2671.0|           0.0|M1176932104|           0.0|           0.0|      0|             0|
# |   1|   DEBIT| 5337.77| C712410124|      41720.0|      36382.23| C195600860|       41898.0|      40348.79|      0|             0|
# +----+--------+--------+-----------+-------------+--------------+-----------+--------------+--------------+-------+--------------+
# only showing top 10 rows

# %%
df.columns
# Out:
# ['step',
#  'type',
#  'amount',
#  'nameOrig',
#  'oldbalanceOrg',
#  'newbalanceOrig',
#  'nameDest',
#  'oldbalanceDest',
#  'newbalanceDest',
#  'isFraud',
#  'isFlaggedFraud']

# %%
df = df.drop('isFraud', 'isFlaggedFraud')

# %%
(
    df.
    groupBy('step').
    count().
    show(n=3)
)
# Out:
# +----+-----+
# |step|count|
# +----+-----+
# |  12|36153|
# |   1| 2708|
# |  13|37515|
# +----+-----+
# only showing top 3 rows

# %%
# steps = df.select('step').distinct().collect()
# for step in steps[:]:
#      _df = df.where(f'step = {step[0]}')
#     # _df.coalesce(1).write.mode('append').option('header', 'true').csv('../data/paysim')
#     _df.coalesce(1).write.mode('append').format('csv').option('header','true').csv('data/paysim')

# %%
# !cd data/paysim/ && ls
# Out:
# part-00000-0248b774-4c6c-40da-8601-23058ce7bad0-c000.csv
# part-00000-03585af6-cf76-4b7e-96ab-2d3323f5e8ac-c000.csv
# part-00000-0484266d-29b0-46b4-9680-c74153161ae0-c000.csv
# part-00000-04af313c-57cb-4d00-8b9b-ab0c16896672-c000.csv
# part-00000-0affab26-cd30-41b6-ab4d-b924826327e2-c000.csv
# part-00000-0c331c10-47fa-4c49-b2b1-7d67581856d7-c000.csv
# part-00000-0f800789-81a1-4fe5-92bd-faecf29a9390-c000.csv
# part-00000-118c6005-6395-4baa-bdf9-9e210544517d-c000.csv
# part-00000-146ece07-fb1d-4b5c-9d34-0a69c1003fc8-c000.csv
# part-00000-14716195-9912-403a-8db7-f2a36c35311e-c000.csv
# part-00000-14eba50c-ed70-4b3b-9341-c9800165fc87-c000.csv
# part-00000-16b8188f-86fd-444a-a60f-f6bae0a5f01f-c000.csv
# part-00000-18fd1995-bb6c-4df4-b669-e18861b1ed46-c000.csv
# part-00000-1ccbf5a3-c873-4065-be63-ecca5fcb3fa4-c000.csv
# part-00000-24287748-3033-4023-b586-21cec7225b44-c000.csv
# part-00000-25a115dd-365f-4c0d-b9c6-273767722e35-c000.csv
# part-00000-2821e853-b7dc-4c75-a6fe-5c2d59237600-c000.csv
# part-00000-2af19103-b1cc-43ae-a866-daab19ce9530-c000.csv
# part-00000-2e2d9e57-6fe3-4ae1-b7d5-0cdcaad00502-c000.csv
# part-00000-33879c1b-b3a1-4b57-8897-969dab4db8bc-c000.csv
# part-00000-35cc0f08-153b-41de-afbe-cebedd046aec-c000.csv
# part-00000-37eadc25-e9db-4886-97c5-a4e5c2c79af4-c000.csv
# part-00000-43e68b58-3bdb-40d1-8534-16da2e1b8b2a-c000.csv
# part-00000-474247c9-93fc-44d7-b0e4-86a1476c5f6c-c000.csv
# part-00000-4cc5c3df-d311-4433-a01f-268ff780cbd9-c000.csv
# part-00000-4f7a384d-3182-40e5-8f0b-9f1278850595-c000.csv
# part-00000-520b81ab-9d89-4bf7-a035-d0d0bdc328c1-c000.csv
# part-00000-52409d0d-85fc-4334-9cf4-0c59a43f4483-c000.csv
# part-00000-54acd5c3-5dc1-49d1-96a1-51f7aa276625-c000.csv
# part-00000-5b22a9d4-1dad-4425-a675-2b2f0ecb04c9-c000.csv
# part-00000-5b9f4326-664d-4f9a-8bec-fa10b16aadd6-c000.csv
# part-00000-60a98a82-c5de-4cba-8bfb-1ed666403d2e-c000.csv
# part-00000-60dcda2d-5085-496d-9d2a-d23885987419-c000.csv
# part-00000-6da2b181-4ee6-4859-b68c-236c50901c4e-c000.csv
# part-00000-71c3093d-cfa3-421e-bead-a95186620a31-c000.csv
# part-00000-78ad6d71-1aa4-43bd-9561-932a60bc6b90-c000.csv
# part-00000-7b813d4c-1e77-44e2-98f0-8bf55df70dde-c000.csv
# part-00000-7f4db869-60d8-4c6d-9c95-bafb630dda90-c000.csv
# part-00000-81c9e6b6-f7b3-457e-ae5e-4444fe8d7eae-c000.csv
# part-00000-85658b18-04ef-4aca-b5b8-2be1685aa0c6-c000.csv
# part-00000-85cb3473-ddb2-4eab-ab46-e85aed601d54-c000.csv
# part-00000-86297e53-d52b-4f52-97b0-5b9f678b6062-c000.csv
# part-00000-872b8594-51ed-4603-aff3-009753438b50-c000.csv
# part-00000-8c99c243-0ee3-47e9-bd93-d56f457d7131-c000.csv
# part-00000-8e9cf447-0003-41bd-a142-8df6a6aa0a10-c000.csv
# part-00000-9364e900-eaba-4471-9190-e0b36ff884b4-c000.csv
# part-00000-9a46a109-af50-487b-bf02-02059a72e8c3-c000.csv
# part-00000-9cdb1812-64ff-4750-83b5-b323714bd8cf-c000.csv
# part-00000-9d7a7209-ab8e-49f0-927b-378265600be3-c000.csv
# part-00000-a09af58d-e829-4b85-90d5-1debaa773025-c000.csv
# part-00000-a4c628a7-e3e7-4cde-b7db-5aff6f533b2a-c000.csv
# part-00000-a8654594-59eb-47b5-afe7-9441159a8689-c000.csv
# part-00000-b001df79-d9f4-423a-9521-48a894976b4f-c000.csv
# part-00000-b05414c7-ac45-4595-b9ee-c6623f461d98-c000.csv
# part-00000-b1eed527-ecfb-47fe-b6d3-7957d7a55e23-c000.csv
# part-00000-b62ca0cd-bf8a-42ef-a5b2-640e6a732a8d-c000.csv
# part-00000-bbeac055-67bd-4a2e-9551-2fc39a800f84-c000.csv
# part-00000-c0fa7ecf-d68f-4c73-bf68-367a93592637-c000.csv
# part-00000-c3bbc8a3-de9e-4fbf-a570-7239baeb5b7e-c000.csv
# part-00000-c451b15b-b9f5-41da-a4cf-eff3c0e2c1b9-c000.csv
# part-00000-c4708fac-badc-4e44-9ce3-8ff7c4609cfb-c000.csv
# part-00000-c63253cb-6a43-464c-9937-47fa34d39106-c000.csv
# part-00000-c7f5d2a3-d05f-4d8a-bb3e-df59241f9bf2-c000.csv
# part-00000-d04eab59-a898-4f30-8043-505342f4fd43-c000.csv
# part-00000-d1ed85fc-cd0f-4f6d-82f0-431abb3bacb7-c000.csv
# part-00000-e49bf945-f32f-4709-a8d0-64c712903202-c000.csv
# part-00000-e599ce65-160d-44e5-a999-361e5e0c8edc-c000.csv
# part-00000-e6e4900f-2e8d-4fce-8c97-e135d570cb61-c000.csv
# part-00000-f81da0ca-e3b3-4a6f-a422-6573fc1cf534-c000.csv
# part-00000-f9e82c91-abfc-47f6-9974-f8b80268772a-c000.csv
# _SUCCESS

# %%
part_filename = 'data/paysim/part-00000-6da2b181-4ee6-4859-b68c-236c50901c4e-c000.csv'

part = (
    spark.
    read.
    format('csv').
    option('header', 'true').
    option('inferSchema', 'true').
    load(part_filename)
)

# %%
(
    part.
    groupBy('step').
    count().
    show()
)
# Out:
# +----+-----+
# |step|count|
# +----+-----+
# |  17|43361|
# +----+-----+

# %% [markdown]
# Let's create a streaming version of this input, we'll read each file one by one as if it was a stream

# %%
dataSchema = part.schema

# %%
dataSchema
# Out:
# StructType([StructField('step', IntegerType(), True), StructField('type', StringType(), True), StructField('amount', DoubleType(), True), StructField('nameOrig', StringType(), True), StructField('oldbalanceOrg', DoubleType(), True), StructField('newbalanceOrig', DoubleType(), True), StructField('nameDest', StringType(), True), StructField('oldbalanceDest', DoubleType(), True), StructField('newbalanceDest', DoubleType(), True)])

# %% [markdown]
# **maxFilesPerTrigger** allows you to control how quickly Spark will read all of the files in the folder. In this example we're limiting the flow of the stream to one file per trigger.

# %%
streaming = (
    spark.readStream.schema(dataSchema).
    option("maxFilesPerTrigger", 1).
    csv("data/paysim/")   
)

# %% [markdown]
# Let's set up a transformation.
#
# The nameDest column is the recipient ID of the transaction.

# %%
dest_count = (
    streaming.
    groupBy('nameDest').
    count().
    orderBy(function.desc('count'))
)

# %% [markdown]
# Now that we have our transformations, we need to specify an output sink for the results. For this example, we're going to write to a memory sink which keeps the results in memory.
#
# We would also need to define how Spark will output the data. In this example, we'll compute output mode (rewriting all of the keys along with their counts after every trigger).
#
# We won't include activityQuery.await.Terminator() because it is required only to prevent the driver process from terminating when the stream is active.
#
# So in order to be able to run this locally in a notebook we won't include it.

# %%
activityQuery = (
    dest_count.
        writeStream.
        queryName('dest_counts').
    format("memory").
    outputMode("complete").
    start()
)


import time

for x in range(50):
    _df = spark.sql(
        """
        SELECT
            *
        FROM
            dest_counts
        WHERE
            nameDest != 'nameDest'
        AND
            count >= 2
        """
    )
    
    if _df.count() > 0:
        _df.show(10)
    time.sleep(0.5)
# Out:
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C2131465140|    9|
# | C499714286|    9|
# |C1760966565|    7|
# |C1239707538|    7|
# |C1968101532|    7|
# |C1139127799|    7|
# | C709613653|    7|
# |C1193495878|    7|
# |C1907159141|    7|
# |C1390358265|    7|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C2131465140|    9|
# | C499714286|    9|
# |C1760966565|    7|
# |C1239707538|    7|
# |C1968101532|    7|
# |C1139127799|    7|
# | C709613653|    7|
# |C1193495878|    7|
# |C1907159141|    7|
# |C1390358265|    7|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   34|
# | C985934102|   33|
# | C564160838|   30|
# |C2083562754|   25|
# | C665576141|   23|
# |C1286084959|   23|
# | C401424608|   22|
# |  C33524623|   22|
# | C998351292|   22|
# |C1023714065|   22|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   34|
# | C985934102|   33|
# | C564160838|   30|
# |C2083562754|   25|
# | C665576141|   23|
# |C1286084959|   23|
# | C401424608|   22|
# |  C33524623|   22|
# | C998351292|   22|
# |C1023714065|   22|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   36|
# |C1590550415|   35|
# | C564160838|   30|
# |C2083562754|   27|
# |C1789550256|   25|
# | C998351292|   25|
# | C665576141|   24|
# | C451111351|   23|
# |C1286084959|   23|
# | C401424608|   22|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   46|
# |C1590550415|   44|
# |C2083562754|   31|
# | C665576141|   30|
# |C1360767589|   30|
# |C1789550256|   30|
# | C564160838|   30|
# | C451111351|   28|
# |C1286084959|   26|
# | C998351292|   25|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   46|
# |C1590550415|   44|
# |C2083562754|   31|
# | C665576141|   30|
# |C1360767589|   30|
# |C1789550256|   30|
# | C564160838|   30|
# | C451111351|   28|
# |C1286084959|   26|
# | C998351292|   25|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   46|
# |C1590550415|   44|
# | C665576141|   32|
# |C1360767589|   31|
# |C2083562754|   31|
# |C1789550256|   30|
# | C564160838|   30|
# | C451111351|   29|
# | C932583850|   27|
# |C1286084959|   26|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   47|
# |C1590550415|   46|
# | C665576141|   35|
# | C451111351|   34|
# |C1360767589|   33|
# |C1789550256|   33|
# | C932583850|   31|
# | C564160838|   31|
# |C2083562754|   31|
# |C1286084959|   29|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   49|
# |C1590550415|   48|
# | C665576141|   35|
# | C451111351|   34|
# |C1789550256|   34|
# |C1360767589|   33|
# |C2083562754|   32|
# | C932583850|   31|
# | C564160838|   31|
# |C1286084959|   29|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   53|
# | C985934102|   51|
# | C665576141|   38|
# | C451111351|   37|
# |C1789550256|   35|
# |C2083562754|   35|
# | C932583850|   34|
# |C1360767589|   34|
# | C564160838|   32|
# | C453211571|   31|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   53|
# | C985934102|   51|
# | C665576141|   38|
# | C451111351|   37|
# |C1789550256|   35|
# |C2083562754|   35|
# | C932583850|   34|
# |C1360767589|   34|
# | C564160838|   32|
# | C453211571|   31|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   54|
# | C985934102|   53|
# | C665576141|   38|
# | C451111351|   38|
# |C1789550256|   36|
# |C1360767589|   35|
# |C2083562754|   35|
# | C932583850|   34|
# | C564160838|   32|
# | C453211571|   31|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   54|
# | C985934102|   53|
# | C665576141|   40|
# | C451111351|   39|
# |C1789550256|   38|
# | C932583850|   36|
# |C1360767589|   36|
# |C2083562754|   35|
# | C248609774|   32|
# | C453211571|   32|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   61|
# | C985934102|   57|
# | C665576141|   49|
# | C451111351|   44|
# |C1789550256|   43|
# |C1360767589|   40|
# |C2083562754|   39|
# | C932583850|   38|
# | C998351292|   38|
# |C1234776885|   38|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   63|
# | C985934102|   60|
# | C665576141|   52|
# | C451111351|   44|
# |C1789550256|   43|
# |C1360767589|   42|
# |C2083562754|   40|
# | C932583850|   39|
# |C1234776885|   39|
# | C998351292|   38|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# |C1590550415|   63|
# | C985934102|   62|
# | C665576141|   54|
# |C1360767589|   45|
# |C1789550256|   45|
# | C451111351|   44|
# |C2083562754|   44|
# | C932583850|   42|
# |C1782113663|   41|
# |C1234776885|   41|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   70|
# |C1590550415|   69|
# | C665576141|   66|
# |C2083562754|   59|
# |C1360767589|   55|
# | C248609774|   53|
# | C451111351|   52|
# |C1286084959|   51|
# | C932583850|   50|
# |  C97730845|   50|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   78|
# | C665576141|   73|
# |C1590550415|   73|
# |C2083562754|   70|
# |C1360767589|   69|
# |C1286084959|   67|
# | C248609774|   62|
# | C451111351|   60|
# | C977993101|   59|
# |  C97730845|   59|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   80|
# | C665576141|   77|
# |C1590550415|   77|
# |C2083562754|   73|
# | C248609774|   71|
# |C1360767589|   71|
# |C1286084959|   71|
# | C451111351|   63|
# | C977993101|   63|
# |  C97730845|   63|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   80|
# | C665576141|   77|
# |C1590550415|   77|
# |C2083562754|   73|
# | C248609774|   71|
# |C1360767589|   71|
# |C1286084959|   71|
# | C451111351|   64|
# |  C97730845|   64|
# | C977993101|   63|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   82|
# | C665576141|   78|
# |C1590550415|   78|
# |C1286084959|   76|
# |C2083562754|   74|
# | C248609774|   73|
# |C1360767589|   71|
# |  C97730845|   67|
# | C451111351|   66|
# | C306206744|   65|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   83|
# | C665576141|   81|
# |C1286084959|   80|
# |C1590550415|   79|
# |C2083562754|   77|
# | C248609774|   76|
# |C1360767589|   74|
# | C451111351|   69|
# |  C97730845|   69|
# | C306206744|   67|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   92|
# |C1286084959|   86|
# | C248609774|   83|
# | C665576141|   83|
# |C1590550415|   81|
# |C2083562754|   81|
# | C977993101|   78|
# |C1360767589|   77|
# | C451111351|   74|
# | C306206744|   74|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   83|
# |C2083562754|   83|
# |C1590550415|   81|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows
#
# +-----------+-----+
# |   nameDest|count|
# +-----------+-----+
# | C985934102|   93|
# | C248609774|   87|
# |C1286084959|   87|
# | C665576141|   84|
# |C2083562754|   83|
# |C1590550415|   82|
# | C977993101|   79|
# |C1360767589|   78|
# | C451111351|   76|
# | C306206744|   75|
# +-----------+-----+
# only showing top 10 rows

# %% [markdown]
# Check if stream is active

# %%
spark.streams.active[0].isActive
# Out:
# True

# %%
activityQuery.status
# Out:
# {'message': 'Processing new data',
#  'isDataAvailable': True,
#  'isTriggerActive': True}

# %% [markdown]
# if we want to turn off the stream, we'll run activityQuery.stop() to reset the query for testing purpose.

# %%
activityQuery.stop()
